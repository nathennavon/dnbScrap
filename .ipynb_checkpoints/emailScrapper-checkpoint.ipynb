# %%
#!pip install selenium
#!pip install webdriver
#!pip install scrapy

# %%
import numpy as np, pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
from time import sleep

from scrapy.selector import Selector
from scrapy.http import HtmlResponse

# %%
#Sector: Janitorial Industry in the U.S.
#page = https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=1

# %% [markdown]
# ## Page Iterator

# %%
"""Collects links to company profile web page by iterating through companyResults
list and subsequent results pages. 
    Steps include:
        1. iterating through links and appending to list
        2. iterating through pages and collecting page data
        Returns: list of company page urls & next page url
"""

page_1 = 'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=1'
page_2 = 'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=2'

driver = webdriver.Chrome()
driver.get(page_1)

html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

#[print(i.get('href')) for i in soup.find_all('a')]#to identify broken urls on page
#items    = pd.read_csv('items.txt', squeeze=True, header=None)#reading broken urls pasted in csv
#pageURLS = ['https://www.dnb.com/' + i for i in items]#list of company pages for 1 page of results 
#pageURLS[:5]

# %%
stateURL = "https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.florida.html?page=1"

# %% [markdown]
# ### Results

# %%
url = "https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page="

pages = []
[pages.append(url + str(i)) for i in range(21)]
pages
# Out:
# ['https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=0',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=1',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=2',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=3',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=4',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=5',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=6',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=7',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=8',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=9',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=10',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=11',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=12',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=13',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=14',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=15',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=16',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=17',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=18',
#  'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=19']

# %%
#First

homeURL = 'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=1'

driver = webdriver.Chrome()
driver.get(homeURL)

html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

links = [i.get('href') for i in soup.find_all('a')]

linksClean = [] 
for i in links: 
    if i != None : 
        linksClean.append(i)

# %%
#Get industry results by state

stateURLs = []

front = "/business-directory/company-information.janitorial-carpet-cleaning-services.us."
back = ".html?page=1"

for i in page_linksClean:
    if (i.startswith(front) & i.endswith(back)):
        stateURLs.append('https://www.dnb.com/' + i)

len(stateURLs)
# Out:
# 53

# %%
#Get company page links from each state

pageLinks = []

for i in stateURLs:

# %% [markdown]
# ### Company Pages

# %%
resultsURL = 'https://www.dnb.com/business-directory/company-information.janitorial-carpet-cleaning-services.us.html?page=1'

driver = webdriver.Chrome()
driver.get(resultsURL)

html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# %%
"""Collects links to individual company pages"""

# page_links = [i.get('href') for i in soup.find_all('a')]

# page_linksClean = [] 
# for i in page_links: 
#     if i != None : 
#         page_linksClean.append(i)
        
profileLinks = []
for i in page_linksClean:
    if i.startswith("/business-directory/company-profiles."):
        profileLinks.append('https://www.dnb.com/' + i)
        
profileLinks

# %% [markdown]
# ## Data Extractor

# %%
#make owner object a list of dictinaries with 
#Owner([{'title':'name'}, {'title':'name'}])

# %%
thedict = {'Business_Name':[], 'Domain':[],'Revenue':[], 'Owner':[] }

for page in pageURLS:
    
    driver = webdriver.Chrome()
    driver.get(page)

    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    
    thedict['Business_Name'].append(soup.find_all('h1')[0].text)
    #thedict['Domain'].append(soup.find('a', {'id':'hero-company-link'}).get('href'))
    #thedict['Revenue'].append()
    #thedict['Owner'].append()
    
    thedict['Domain'].append(Selector(text=html).xpath('//*[@id="hero-company-link"]/text()').get())
    thedict['Revenue'].append(Selector(text=html).xpath('//*[@id="content"]/div[2]/div/div[3]/div/div/div/div/div[2]/div[1]/div[2]/text()').get())
    thedict['Owner'].append(Selector(text=html).xpath('//*[@id="content"]/div[2]/div/div[8]/div/div[2]/div[2]/div/div/div/ul/li[1]/div[1]/text()').get())
    driver.close()

df = pd.DataFrame(thedict)
df.to_csv('Janitorial_Industry.csv', index=False)
df.head(8)
# Out:
#                          Business_Name                        Domain  \
# 0         C&H Industrial Services Inc.  www.chindustrialservices.com
# 1                  Cdrsvm Holding, LLC                          None
# 2       Terminix Global Holdings, Inc.         www.servicemaster.com
# 3             Gca Services Group, Inc.           www.gcaservices.com
# 4             SMS Holdings Corporation           www.smsholdings.com
# 5              Crothall Services Group              www.crothall.com
# 6  ISS Facility Services Holding, Inc.              www.issworld.com
# 7                     ISS Holding Inc.              www.issworld.com
#
#            Revenue             Owner
# 0    $8.57 billion       David Cross
# 1    $3.00 billion      Nikhil Varty
# 2    $2.99 billion      Nikhil Varty
# 3    $1.24 billion     Robert Norton
# 4  $706.45 million      Keith Walken
# 5  $655.22 million      Bobby Kutteh
# 6  $486.97 million  Jennifer Bonilla
# 7  $486.97 million  Jennifer Bonilla

# %%
soup.find('div', {'class':'rev_title_number'}).get_text()
# Out:
# '$101.18 million USD\n\n\n'

# %%
Selector(text=html).xpath('//*[@id="content"]/div[2]/div/div[3]/div/div/div/div/div[2]/div[1]/div[2]/text()').get()
# Out:
# '$101.18 million'

# %% [markdown]
# ## Email Scrapper

# %%
df = pd.read_csv('Janitorial_Industry.csv')
#df = df.dropna(inplace=True)
print(df.shape)
df.head()
# Out:
# (50, 4)
#                     Business_Name                        Domain  \
# 0    C&H Industrial Services Inc.  www.chindustrialservices.com
# 1             Cdrsvm Holding, LLC                           NaN
# 2  Terminix Global Holdings, Inc.         www.servicemaster.com
# 3        Gca Services Group, Inc.           www.gcaservices.com
# 4        SMS Holdings Corporation           www.smsholdings.com
#
#            Revenue          Owner
# 0    $8.57 billion    David Cross
# 1    $3.00 billion   Nikhil Varty
# 2    $2.99 billion   Nikhil Varty
# 3    $1.24 billion  Robert Norton
# 4  $706.45 million   Keith Walken

# %%
df.dropna(inplace=True)
df
# Out:
#                                       Business_Name  \
# 0                      C&H Industrial Services Inc.
# 2                    Terminix Global Holdings, Inc.
# 3                          Gca Services Group, Inc.
# 4                          SMS Holdings Corporation
# 5                           Crothall Services Group
# 6               ISS Facility Services Holding, Inc.
# 7                                  ISS Holding Inc.
# 8                       ISS Facility Services, Inc.
# 9                     ABM Janitorial Services, Inc.
# 10  Aramark Management Services Limited Partnership
# 11                Thompson Construction Group, Inc.
# 12                    Atalian Global Services, Inc.
# 13                             Aquilex Holdings LLC
# 14                                     Leadec Corp.
# 15                  Corporation Service Company Inc
# 16             Diversified Maintenance Systems, LLC
# 17                  Merry Maids Limited Partnership
# 18                                    Ermc II, L.P.
# 19                          Marsden Holding, L.L.C.
# 30                www.emsinc.com  $201.25 million              David A Bego
# 32             www.hydrochem.com  $191.28 million                Brad Clark
# 33              www.sylvania.com  $189.15 million                Jes Hansen
# 34          www.harvardmaint.com  $181.22 million          Stanley K Doobin
# 35           www.flagshipinc.com  $159.83 million             David M Pasek
# 36       www.blackmonmooring.com  $158.71 million           Ginger Blackmon
# 37       www.blackmonmooring.com  $155.26 million             Kirk Blackmon
# 38             www.caravanfm.com  $151.24 million        Brandon J Bordeaux
# 39      www.usiservicesgroup.com  $146.03 million        Frederick Goldring
# 40             www.kimcoserv.com  $145.80 million             Sandeep Gupta
# 41       www.emcorfacilities.com  $142.73 million          Michael Mcelrath
# 42               www.servpro.com  $136.07 million             Susan L Steen
# 43               www.servpro.com  $136.07 million        Sue Isaacson Steen
# 44             www.mbmonline.com  $124.16 million             Theodore Haas
# 45            www.ugl-unicco.com  $118.59 million           George A Keches
# 46      www.janikingcleaning.com  $117.04 million  JAMES A CAVANAUGH Junior
# 48       www.lacostaservices.com  $101.87 million                Karla Mota
# 49             www.acvenviro.com  $101.18 million           Andrew Shackett

# %%
i = 0 

owner = df.Owner[i]
domain = df.Domain[i][4:]

search = owner + ' ' + '@' + domain
print(search)
# Out:
# David Cross @chindustrialservices.com

# %%
owner = df.Owner
domain = df.Domain

i = 0
while(i < 20):
    print(owner[i] + ' ' + '@' + domain[i][4:])
    i+=1
# Out:
# David Cross @chindustrialservices.com
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-99d2ea1a8339> in <module>
#       4 i = 0
#       5 while(i < 20):
# ----> 6     print(owner[i] + ' ' + '@' + domain[i][4:])
#       7     i+=1
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
searchDict = {'Search':[]}
for i in df[i]:
    searchDict['Search'].append(df.Owner[i] + ' ' + '@' + df.Domain[i][4:])
    
print(searchDict[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Andrew Shackett'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-da8e76bdca45> in <module>
#       1 searchDict = {'Search':[]}
# ----> 2 for i in df[i]:
#       3     searchDict['Search'].append(df.Owner[i] + ' ' + '@' + df.Domain[i][4])
#       4
#       5 print(searchDict[0])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Andrew Shackett'

# %%
emailDict = {'Email':[]}

def emailGen():
    
    return()

# %%
"""

links = soup.find_all('a')
for link in links:
    print(link.get('href'))

  """
#soup.find_all('')
 
#soup.find_all('div',{'id':'companyResults'},{'class':'col-md-12 data'})
#soup.find_all('div',{'id':'companyResults'},{'class':'col-md-6'})
#soup.find_all('a').get('href')

#links = soup.find_all('a')
#for link in links:
    #print(link.contents[0])
    #print(link.get('href'))
    #print(link.attrs)
     
#print(soup.find_all('a')[100].get('href'))
#for link in links:
#    print(link.get('href'))


#soup.find_all('div',{'class':'col-md-6'},'a')
#[0].text
#soup.html.title.text
#Selector(text=html).xpath('//*[@id="companyResults"]/div[3]/div[1]/a').get()

#d = driver.find_element_by_xpath('//*[@id="companyResults"]/div[2]/div[1]/a')
#d.click()
#d.send_keys('ENTER')

# %%
for i,page in enumerate(pageURLS[:3]):
    
    driver = webdriver.Chrome()
    driver.get(page)

    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    
    df['Business_Name'].iloc[i] = soup.find_all('h1')[0].text
    df['Domain'].iloc[i] = soup.find('a', {'id':'hero-company-link'})

#     df['Domain'].iloc[i] = Selector(text=html).xpath('//*[@id="hero-company-link"]/text()').get()
    df['Revenue'].iloc[i] = Selector(text=html).xpath('//*[@id="content"]/div[2]/div/div[3]/div/div/div/div/div[2]/div[1]/div[2]/text()').get()
    df['Owner'].iloc[i] = Selector(text=html).xpath('//*[@id="content"]/div[2]/div/div[8]/div/div[2]/div[2]/div/div/div/ul/li[1]/div[1]/text()').get()
    df['Email'].iloc[i] = 'null'
    driver.close()
df.head()

# %%
driver = webdriver.Chrome()
driver.get(pageURLS[5])

html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

df['Business_Name'] = soup.find_all('h1')[0].text
df['Domain'].iloc[0]        = Selector(text=html).xpath('//*[@id="hero-company-link"]/text()').get()
df['Revenue'].iloc[0]       = Selector(text=html).xpath('//*[@id="content"]/div[2]/div/div[3]/div/div/div/div/div[2]/div[1]/div[2]/text()').get()
df['Owner'].iloc[0]         = Selector(text=html).xpath('//*[@id="content"]/div[2]/div/div[8]/div/div[2]/div[2]/div/div/div/ul/li[1]/div[1]/text()').get()
df['Email'].iloc[0]         = 'null'

driver.close()
df
# Out:
#          Business_Name Domain        Revenue         Owner Email
# 0  Cdrsvm Holding, LLC   None  $3.00 billion  Nikhil Varty  null

# %%
""""""

url = 'https://www.dnb.com/business-directory/company-profiles.ch_industrial_services_inc.a58e3ce2fbea082f0f5486dfac5cccc8.html'

driver = webdriver.Chrome()
driver.get(url)

html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

driver.close()
#df['business_name'] = soup.find_all('h1')[0].text
#df['domain'] = Selector(text=html).xpath('//*[@id="hero-company-link"]/text()').get()
#df['revenue'] = Selector(text=html).xpath('//*[@id="content"]/div[2]/div/div[3]/div/div/div/div/div[2]/div[1]/div[2]/text()').get()
#df['owner'] = Selector(text=html).xpath('//*[@id="content"]/div[2]/div/div[8]/div/div[2]/div[2]/div/div/div/ul/li[1]/div[1]/text()').get()

# %%
#Selector(text=html).xpath('').get()

#d = driver.find_element_by_xpath('')
#d.click()
#d.send_keys('ENTER')

#soup.find_all('a', {'class':'ext-icon'})
#soup.find_all('div',{'class':'web'},'a')[0].text
#soup.html.title.text

#Selector(text=html).xpath('//*[@id="content"]/div[2]/div/div[1]/div/div/div/div/nav/div[2]/ol/li[8]/span/span').extract()
#Selector(text=html).xpath('').get()

#driver.click_link_by_href('')
#driver.find_element_by_xpath('').send_keys('ENTER')

#driver.find_element_by_xpath('//*[@id="companyResults"]/div[5]/div[1]/a').context#.send_keys('ENTER')
#driver.find_element_by_xpath('//*[@id="companyResults"]/div[50]/div[1]/a').click()
#driver.find_element_by_link_text("The ServiceMaster Company LLC").click()
#driver.find_element_by_link_text("The ServiceMaster Company LLC").send_keys('ENTER')
#driver.find_element_by_xpath("").click()
#driver.find_element_by_class_name("page").click()

#driver.find_element_by_class_name("col-md-6")#.click()
#driver.find_element_by_css_selector('#companyResults > div:nth-child(5) > div.col-md-6 > a').click()
